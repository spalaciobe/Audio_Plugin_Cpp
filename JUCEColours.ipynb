# %%
import re

# The input text containing color definitions
input_text = """
const Colour 	transparentBlack { 0 }
 
const Colour 	transparentWhite { 0x00ffffff }
 
const Colour 	aliceblue { 0xfff0f8ff }
 
const Colour 	antiquewhite { 0xfffaebd7 }
 
const Colour 	aqua { 0xff00ffff }
 
const Colour 	aquamarine { 0xff7fffd4 }
 
const Colour 	azure { 0xfff0ffff }
 
const Colour 	beige { 0xfff5f5dc }
 
const Colour 	bisque { 0xffffe4c4 }
 
const Colour 	black { 0xff000000 }
 
const Colour 	blanchedalmond { 0xffffebcd }
 
const Colour 	blue { 0xff0000ff }
 
const Colour 	blueviolet { 0xff8a2be2 }
 
const Colour 	brown { 0xffa52a2a }
 
const Colour 	burlywood { 0xffdeb887 }
 
const Colour 	cadetblue { 0xff5f9ea0 }
 
const Colour 	chartreuse { 0xff7fff00 }
 
const Colour 	chocolate { 0xffd2691e }
 
const Colour 	coral { 0xffff7f50 }
 
const Colour 	cornflowerblue { 0xff6495ed }
 
const Colour 	cornsilk { 0xfffff8dc }
 
const Colour 	crimson { 0xffdc143c }
 
const Colour 	cyan { 0xff00ffff }
 
const Colour 	darkblue { 0xff00008b }
 
const Colour 	darkcyan { 0xff008b8b }
 
const Colour 	darkgoldenrod { 0xffb8860b }
 
const Colour 	darkgrey { 0xff555555 }
 
const Colour 	darkgreen { 0xff006400 }
 
const Colour 	darkkhaki { 0xffbdb76b }
 
const Colour 	darkmagenta { 0xff8b008b }
 
const Colour 	darkolivegreen { 0xff556b2f }
 
const Colour 	darkorange { 0xffff8c00 }
 
const Colour 	darkorchid { 0xff9932cc }
 
const Colour 	darkred { 0xff8b0000 }
 
const Colour 	darksalmon { 0xffe9967a }
 
const Colour 	darkseagreen { 0xff8fbc8f }
 
const Colour 	darkslateblue { 0xff483d8b }
 
const Colour 	darkslategrey { 0xff2f4f4f }
 
const Colour 	darkturquoise { 0xff00ced1 }
 
const Colour 	darkviolet { 0xff9400d3 }
 
const Colour 	deeppink { 0xffff1493 }
 
const Colour 	deepskyblue { 0xff00bfff }
 
const Colour 	dimgrey { 0xff696969 }
 
const Colour 	dodgerblue { 0xff1e90ff }
 
const Colour 	firebrick { 0xffb22222 }
 
const Colour 	floralwhite { 0xfffffaf0 }
 
const Colour 	forestgreen { 0xff228b22 }
 
const Colour 	fuchsia { 0xffff00ff }
 
const Colour 	gainsboro { 0xffdcdcdc }
 
const Colour 	ghostwhite { 0xfff8f8ff }
 
const Colour 	gold { 0xffffd700 }
 
const Colour 	goldenrod { 0xffdaa520 }
 
const Colour 	grey { 0xff808080 }
 
const Colour 	green { 0xff008000 }
 
const Colour 	greenyellow { 0xffadff2f }
 
const Colour 	honeydew { 0xfff0fff0 }
 
const Colour 	hotpink { 0xffff69b4 }
 
const Colour 	indianred { 0xffcd5c5c }
 
const Colour 	indigo { 0xff4b0082 }
 
const Colour 	ivory { 0xfffffff0 }
 
const Colour 	khaki { 0xfff0e68c }
 
const Colour 	lavender { 0xffe6e6fa }
 
const Colour 	lavenderblush { 0xfffff0f5 }
 
const Colour 	lawngreen { 0xff7cfc00 }
 
const Colour 	lemonchiffon { 0xfffffacd }
 
const Colour 	lightblue { 0xffadd8e6 }
 
const Colour 	lightcoral { 0xfff08080 }
 
const Colour 	lightcyan { 0xffe0ffff }
 
const Colour 	lightgoldenrodyellow { 0xfffafad2 }
 
const Colour 	lightgreen { 0xff90ee90 }
 
const Colour 	lightgrey { 0xffd3d3d3 }
 
const Colour 	lightpink { 0xffffb6c1 }
 
const Colour 	lightsalmon { 0xffffa07a }
 
const Colour 	lightseagreen { 0xff20b2aa }
 
const Colour 	lightskyblue { 0xff87cefa }
 
const Colour 	lightslategrey { 0xff778899 }
 
const Colour 	lightsteelblue { 0xffb0c4de }
 
const Colour 	lightyellow { 0xffffffe0 }
 
const Colour 	lime { 0xff00ff00 }
 
const Colour 	limegreen { 0xff32cd32 }
 
const Colour 	linen { 0xfffaf0e6 }
 
const Colour 	magenta { 0xffff00ff }
 
const Colour 	maroon { 0xff800000 }
 
const Colour 	mediumaquamarine { 0xff66cdaa }
 
const Colour 	mediumblue { 0xff0000cd }
 
const Colour 	mediumorchid { 0xffba55d3 }
 
const Colour 	mediumpurple { 0xff9370db }
 
const Colour 	mediumseagreen { 0xff3cb371 }
 
const Colour 	mediumslateblue { 0xff7b68ee }
 
const Colour 	mediumspringgreen { 0xff00fa9a }
 
const Colour 	mediumturquoise { 0xff48d1cc }
 
const Colour 	mediumvioletred { 0xffc71585 }
 
const Colour 	midnightblue { 0xff191970 }
 
const Colour 	mintcream { 0xfff5fffa }
 
const Colour 	mistyrose { 0xffffe4e1 }
 
const Colour 	moccasin { 0xffffe4b5 }
 
const Colour 	navajowhite { 0xffffdead }
 
const Colour 	navy { 0xff000080 }
 
const Colour 	oldlace { 0xfffdf5e6 }
 
const Colour 	olive { 0xff808000 }
 
const Colour 	olivedrab { 0xff6b8e23 }
 
const Colour 	orange { 0xffffa500 }
 
const Colour 	orangered { 0xffff4500 }
 
const Colour 	orchid { 0xffda70d6 }
 
const Colour 	palegoldenrod { 0xffeee8aa }
 
const Colour 	palegreen { 0xff98fb98 }
 
const Colour 	paleturquoise { 0xffafeeee }
 
const Colour 	palevioletred { 0xffdb7093 }
 
const Colour 	papayawhip { 0xffffefd5 }
 
const Colour 	peachpuff { 0xffffdab9 }
 
const Colour 	peru { 0xffcd853f }
 
const Colour 	pink { 0xffffc0cb }
 
const Colour 	plum { 0xffdda0dd }
 
const Colour 	powderblue { 0xffb0e0e6 }
 
const Colour 	purple { 0xff800080 }
 
const Colour 	rebeccapurple { 0xff663399 }
 
const Colour 	red { 0xffff0000 }
 
const Colour 	rosybrown { 0xffbc8f8f }
 
const Colour 	royalblue { 0xff4169e1 }
 
const Colour 	saddlebrown { 0xff8b4513 }
 
const Colour 	salmon { 0xfffa8072 }
 
const Colour 	sandybrown { 0xfff4a460 }
 
const Colour 	seagreen { 0xff2e8b57 }
 
const Colour 	seashell { 0xfffff5ee }
 
const Colour 	sienna { 0xffa0522d }
 
const Colour 	silver { 0xffc0c0c0 }
 
const Colour 	skyblue { 0xff87ceeb }
 
const Colour 	slateblue { 0xff6a5acd }
 
const Colour 	slategrey { 0xff708090 }
 
const Colour 	snow { 0xfffffafa }
 
const Colour 	springgreen { 0xff00ff7f }
 
const Colour 	steelblue { 0xff4682b4 }
 
const Colour 	tan { 0xffd2b48c }
 
const Colour 	teal { 0xff008080 }
 
const Colour 	thistle { 0xffd8bfd8 }
 
const Colour 	tomato { 0xffff6347 }
 
const Colour 	turquoise { 0xff40e0d0 }
 
const Colour 	violet { 0xffee82ee }
 
const Colour 	wheat { 0xfff5deb3 }
 
const Colour 	white { 0xffffffff }
 
const Colour 	whitesmoke { 0xfff5f5f5 }
 
const Colour 	yellow { 0xffffff00 }
 
const Colour 	yellowgreen { 0xff9acd32 }
"""

# Regular expression to match the color definitions
pattern = r"const Colour\s+(\w+)\s+\{\s*(0x[0-9a-fA-F]+|0)\s*\}"

# Function to convert hex color to ANSI escape code
def hex_to_ansi(hex_color):
    if hex_color == '0':
        return "\033[48;2;0;0;0m  \033[0m"  # Black square for transparent (0)

    # Remove the '0x' prefix
    hex_color = hex_color.lstrip('0x')

    # Extract RGB components (last 6 characters for RGB)
    if len(hex_color) == 8:  # ARGB
        rgb_color = hex_color[2:]  # Remove alpha (first 2 characters)
    elif len(hex_color) == 6:  # RGB
        rgb_color = hex_color
    else:
        raise ValueError("Invalid hex color format.")

    # Extract R, G, B values
    r = int(rgb_color[0:2], 16)
    g = int(rgb_color[2:4], 16)
    b = int(rgb_color[4:6], 16)

    # Create ANSI escape code for the background color
    return f"\033[48;2;{r};{g};{b}m  \033[0m"  # ANSI escape for the colored square

# Extract color names and their squares
color_list = []
matches = re.findall(pattern, input_text)
for match in matches:
    color_name = match[0]  # The color name
    hex_value = match[1]  # The hex value
    square = hex_to_ansi(hex_value)  # Create a colored square
    color_list.append((color_name, hex_value, square))  # Add to list

# Display the colors with their squares
for color_name, hex_value, square in color_list:
    print(f"Color Name: {color_name}, Hex Value: {hex_value}, Square: {square}")
# Out:
# Color Name: transparentBlack, Hex Value: 0, Square:
# Color Name: transparentWhite, Hex Value: 0x00ffffff, Square:
# Color Name: aliceblue, Hex Value: 0xfff0f8ff, Square:
# Color Name: antiquewhite, Hex Value: 0xfffaebd7, Square:
# Color Name: aqua, Hex Value: 0xff00ffff, Square:
# Color Name: aquamarine, Hex Value: 0xff7fffd4, Square:
# Color Name: azure, Hex Value: 0xfff0ffff, Square:
# Color Name: beige, Hex Value: 0xfff5f5dc, Square:
# Color Name: bisque, Hex Value: 0xffffe4c4, Square:
# Color Name: black, Hex Value: 0xff000000, Square:
# Color Name: blanchedalmond, Hex Value: 0xffffebcd, Square:
# Color Name: blue, Hex Value: 0xff0000ff, Square:
# Color Name: blueviolet, Hex Value: 0xff8a2be2, Square:
# Color Name: brown, Hex Value: 0xffa52a2a, Square:
# Color Name: burlywood, Hex Value: 0xffdeb887, Square:
# Color Name: cadetblue, Hex Value: 0xff5f9ea0, Square:
# Color Name: chartreuse, Hex Value: 0xff7fff00, Square:
# Color Name: chocolate, Hex Value: 0xffd2691e, Square:
# Color Name: coral, Hex Value: 0xffff7f50, Square:
# Color Name: cornflowerblue, Hex Value: 0xff6495ed, Square:
# Color Name: cornsilk, Hex Value: 0xfffff8dc, Square:
# Color Name: crimson, Hex Value: 0xffdc143c, Square:
# Color Name: cyan, Hex Value: 0xff00ffff, Square:
# Color Name: darkblue, Hex Value: 0xff00008b, Square:
# Color Name: darkcyan, Hex Value: 0xff008b8b, Square:
# Color Name: darkgoldenrod, Hex Value: 0xffb8860b, Square:
# Color Name: darkgrey, Hex Value: 0xff555555, Square:
# Color Name: darkgreen, Hex Value: 0xff006400, Square:
# Color Name: darkkhaki, Hex Value: 0xffbdb76b, Square:
# Color Name: darkmagenta, Hex Value: 0xff8b008b, Square:
# Color Name: darkolivegreen, Hex Value: 0xff556b2f, Square:
# Color Name: darkorange, Hex Value: 0xffff8c00, Square:
# Color Name: darkorchid, Hex Value: 0xff9932cc, Square:
# Color Name: darkred, Hex Value: 0xff8b0000, Square:
# Color Name: darksalmon, Hex Value: 0xffe9967a, Square:
# Color Name: darkseagreen, Hex Value: 0xff8fbc8f, Square:
# Color Name: darkslateblue, Hex Value: 0xff483d8b, Square:
# Color Name: darkslategrey, Hex Value: 0xff2f4f4f, Square:
# Color Name: darkturquoise, Hex Value: 0xff00ced1, Square:
# Color Name: darkviolet, Hex Value: 0xff9400d3, Square:
# Color Name: deeppink, Hex Value: 0xffff1493, Square:
# Color Name: deepskyblue, Hex Value: 0xff00bfff, Square:
# Color Name: dimgrey, Hex Value: 0xff696969, Square:
# Color Name: dodgerblue, Hex Value: 0xff1e90ff, Square:
# Color Name: firebrick, Hex Value: 0xffb22222, Square:
# Color Name: floralwhite, Hex Value: 0xfffffaf0, Square:
# Color Name: forestgreen, Hex Value: 0xff228b22, Square:
# Color Name: fuchsia, Hex Value: 0xffff00ff, Square:
# Color Name: gainsboro, Hex Value: 0xffdcdcdc, Square:
# Color Name: ghostwhite, Hex Value: 0xfff8f8ff, Square:
# Color Name: gold, Hex Value: 0xffffd700, Square:
# Color Name: goldenrod, Hex Value: 0xffdaa520, Square:
# Color Name: grey, Hex Value: 0xff808080, Square:
# Color Name: green, Hex Value: 0xff008000, Square:
# Color Name: greenyellow, Hex Value: 0xffadff2f, Square:
# Color Name: honeydew, Hex Value: 0xfff0fff0, Square:
# Color Name: hotpink, Hex Value: 0xffff69b4, Square:
# Color Name: indianred, Hex Value: 0xffcd5c5c, Square:
# Color Name: indigo, Hex Value: 0xff4b0082, Square:
# Color Name: ivory, Hex Value: 0xfffffff0, Square:
# Color Name: khaki, Hex Value: 0xfff0e68c, Square:
# Color Name: lavender, Hex Value: 0xffe6e6fa, Square:
# Color Name: lavenderblush, Hex Value: 0xfffff0f5, Square:
# Color Name: lawngreen, Hex Value: 0xff7cfc00, Square:
# Color Name: lemonchiffon, Hex Value: 0xfffffacd, Square:
# Color Name: lightblue, Hex Value: 0xffadd8e6, Square:
# Color Name: lightcoral, Hex Value: 0xfff08080, Square:
# Color Name: lightcyan, Hex Value: 0xffe0ffff, Square:
# Color Name: lightgoldenrodyellow, Hex Value: 0xfffafad2, Square:
# Color Name: lightgreen, Hex Value: 0xff90ee90, Square:
# Color Name: lightgrey, Hex Value: 0xffd3d3d3, Square:
# Color Name: lightpink, Hex Value: 0xffffb6c1, Square:
# Color Name: lightsalmon, Hex Value: 0xffffa07a, Square:
# Color Name: lightseagreen, Hex Value: 0xff20b2aa, Square:
# Color Name: lightskyblue, Hex Value: 0xff87cefa, Square:
# Color Name: lightslategrey, Hex Value: 0xff778899, Square:
# Color Name: lightsteelblue, Hex Value: 0xffb0c4de, Square:
# Color Name: lightyellow, Hex Value: 0xffffffe0, Square:
# Color Name: lime, Hex Value: 0xff00ff00, Square:
# Color Name: limegreen, Hex Value: 0xff32cd32, Square:
# Color Name: linen, Hex Value: 0xfffaf0e6, Square:
# Color Name: magenta, Hex Value: 0xffff00ff, Square:
# Color Name: maroon, Hex Value: 0xff800000, Square:
# Color Name: mediumaquamarine, Hex Value: 0xff66cdaa, Square:
# Color Name: mediumblue, Hex Value: 0xff0000cd, Square:
# Color Name: mediumorchid, Hex Value: 0xffba55d3, Square:
# Color Name: mediumpurple, Hex Value: 0xff9370db, Square:
# Color Name: mediumseagreen, Hex Value: 0xff3cb371, Square:
# Color Name: mediumslateblue, Hex Value: 0xff7b68ee, Square:
# Color Name: mediumspringgreen, Hex Value: 0xff00fa9a, Square:
# Color Name: mediumturquoise, Hex Value: 0xff48d1cc, Square:
# Color Name: mediumvioletred, Hex Value: 0xffc71585, Square:
# Color Name: midnightblue, Hex Value: 0xff191970, Square:
# Color Name: mintcream, Hex Value: 0xfff5fffa, Square:
# Color Name: mistyrose, Hex Value: 0xffffe4e1, Square:
# Color Name: moccasin, Hex Value: 0xffffe4b5, Square:
# Color Name: navajowhite, Hex Value: 0xffffdead, Square:
# Color Name: navy, Hex Value: 0xff000080, Square:
# Color Name: oldlace, Hex Value: 0xfffdf5e6, Square:
# Color Name: olive, Hex Value: 0xff808000, Square:
# Color Name: olivedrab, Hex Value: 0xff6b8e23, Square:
# Color Name: orange, Hex Value: 0xffffa500, Square:
# Color Name: orangered, Hex Value: 0xffff4500, Square:
# Color Name: orchid, Hex Value: 0xffda70d6, Square:
# Color Name: palegoldenrod, Hex Value: 0xffeee8aa, Square:
# Color Name: palegreen, Hex Value: 0xff98fb98, Square:
# Color Name: paleturquoise, Hex Value: 0xffafeeee, Square:
# Color Name: palevioletred, Hex Value: 0xffdb7093, Square:
# Color Name: papayawhip, Hex Value: 0xffffefd5, Square:
# Color Name: peachpuff, Hex Value: 0xffffdab9, Square:
# Color Name: peru, Hex Value: 0xffcd853f, Square:
# Color Name: pink, Hex Value: 0xffffc0cb, Square:
# Color Name: plum, Hex Value: 0xffdda0dd, Square:
# Color Name: powderblue, Hex Value: 0xffb0e0e6, Square:
# Color Name: purple, Hex Value: 0xff800080, Square:
# Color Name: rebeccapurple, Hex Value: 0xff663399, Square:
# Color Name: red, Hex Value: 0xffff0000, Square:
# Color Name: rosybrown, Hex Value: 0xffbc8f8f, Square:
# Color Name: royalblue, Hex Value: 0xff4169e1, Square:
# Color Name: saddlebrown, Hex Value: 0xff8b4513, Square:
# Color Name: salmon, Hex Value: 0xfffa8072, Square:
# Color Name: sandybrown, Hex Value: 0xfff4a460, Square:
# Color Name: seagreen, Hex Value: 0xff2e8b57, Square:
# Color Name: seashell, Hex Value: 0xfffff5ee, Square:
# Color Name: sienna, Hex Value: 0xffa0522d, Square:
# Color Name: silver, Hex Value: 0xffc0c0c0, Square:
# Color Name: skyblue, Hex Value: 0xff87ceeb, Square:
# Color Name: slateblue, Hex Value: 0xff6a5acd, Square:
# Color Name: slategrey, Hex Value: 0xff708090, Square:
# Color Name: snow, Hex Value: 0xfffffafa, Square:
# Color Name: springgreen, Hex Value: 0xff00ff7f, Square:
# Color Name: steelblue, Hex Value: 0xff4682b4, Square:
# Color Name: tan, Hex Value: 0xffd2b48c, Square:
# Color Name: teal, Hex Value: 0xff008080, Square:
# Color Name: thistle, Hex Value: 0xffd8bfd8, Square:
# Color Name: tomato, Hex Value: 0xffff6347, Square:
# Color Name: turquoise, Hex Value: 0xff40e0d0, Square:
# Color Name: violet, Hex Value: 0xffee82ee, Square:
# Color Name: wheat, Hex Value: 0xfff5deb3, Square:
# Color Name: white, Hex Value: 0xffffffff, Square:
# Color Name: whitesmoke, Hex Value: 0xfff5f5f5, Square:
# Color Name: yellow, Hex Value: 0xffffff00, Square:
# Color Name: yellowgreen, Hex Value: 0xff9acd32, Square:
